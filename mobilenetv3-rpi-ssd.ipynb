# %% [markdown]
# # MobileNetV3-rpi with SSD

# %%
from model import MobileNetV3_RPiWide, BlockNoDw, hswish
import torch
from torch import nn
from torch.nn import Conv2d, Sequential, ModuleList, BatchNorm2d
import torch.nn.functional as F
import config
from torchinfo import summary
from ssd import SSD

# %%
# NOTE: input size is 480, 288 (1, 3, 288, 480)

width_mult = 1.0
num_classes = 2

model = MobileNetV3_RPiWide(width_mult=width_mult, num_classes=num_classes).eval()
base_net = model.features
base_net
# Out:
# Sequential(
#   (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): hswish()
#   (3): BlockNoDw(
#     (se): SeModule(
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(8, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): Conv2d(2, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): hsigmoid()
#       )
#     )
#     (conv1): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nolinear1): ReLU(inplace=True)
#     (conv2): Conv2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (4): BlockNoDw(
#     (conv1): Conv2d(8, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nolinear1): ReLU(inplace=True)
#     (conv2): Conv2d(72, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (5): BlockNoDw(
#     (conv1): Conv2d(12, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nolinear1): ReLU(inplace=True)
#     (conv2): Conv2d(88, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (6): BlockNoDw(
#     (se): SeModule(
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(20, 5, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): Conv2d(5, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): hsigmoid()
#       )
#     )
#     (conv1): Conv2d(12, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nolinear1): hswish()
#     (conv2): Conv2d(96, 20, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#     (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (7): BlockNoDw(
#     (se): SeModule(
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(20, 5, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): Conv2d(5, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): hsigmoid()
#       )
#     )
#     (conv1): Conv2d(20, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nolinear1): hswish()
#     (conv2): Conv2d(240, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (8): BlockNoDw(
#     (se): SeModule(
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(20, 5, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): Conv2d(5, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): hsigmoid()
#       )
#     )
#     (conv1): Conv2d(20, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nolinear1): hswish()
#     (conv2): Conv2d(240, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (9): BlockNoDw(
#     (se): SeModule(
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): hsigmoid()
#       )
#     )
#     (conv1): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nolinear1): hswish()
#     (conv2): Conv2d(120, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential(
#       (0): Conv2d(20, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (10): BlockNoDw(
#     (se): SeModule(
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): hsigmoid()
#       )
#     )
#     (conv1): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nolinear1): hswish()
#     (conv2): Conv2d(144, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (11): BlockNoDw(
#     (se): SeModule(
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): hsigmoid()
#       )
#     )
#     (conv1): Conv2d(24, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nolinear1): hswish()
#     (conv2): Conv2d(288, 48, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#     (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (12): BlockNoDw(
#     (se): SeModule(
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): hsigmoid()
#       )
#     )
#     (conv1): Conv2d(48, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nolinear1): hswish()
#     (conv2): Conv2d(576, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (13): BlockNoDw(
#     (se): SeModule(
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): hsigmoid()
#       )
#     )
#     (conv1): Conv2d(48, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nolinear1): hswish()
#     (conv2): Conv2d(576, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (shortcut): Sequential()
#   )
#   (14): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (15): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): hswish()
# )

# %%
out = base_net(torch.randn(1, 3, 300, 300))
out.shape
# Out:
# torch.Size([1, 288, 10, 10])

# %%
source_layer_indexes = [ 11, 17 ]
extras = ModuleList([
    BlockNoDw(3, 288, 256, 512, hswish(), None, stride=2),
    BlockNoDw(3, 512, 128, 256, hswish(), None, stride=2),
    BlockNoDw(3, 256, 128, 256, hswish(), None, stride=2),
    BlockNoDw(3, 256, 64, 64, hswish(), None, stride=2)
])

regression_headers = ModuleList([
    Conv2d(in_channels=round(24 * width_mult), out_channels=6 * 4, kernel_size=3, padding=1),
    Conv2d(in_channels=288, out_channels=6 * 4, kernel_size=3, padding=1),
    Conv2d(in_channels=512, out_channels=6 * 4, kernel_size=3, padding=1),
    Conv2d(in_channels=256, out_channels=6 * 4, kernel_size=3, padding=1),
    Conv2d(in_channels=256, out_channels=6 * 4, kernel_size=3, padding=1),
    Conv2d(in_channels=64, out_channels=6 * 4, kernel_size=1),
])

classification_headers = ModuleList([
    Conv2d(in_channels=round(24 * width_mult), out_channels=6 * num_classes, kernel_size=3, padding=1),
    Conv2d(in_channels=288, out_channels=6 * num_classes, kernel_size=3, padding=1),
    Conv2d(in_channels=512, out_channels=6 * num_classes, kernel_size=3, padding=1),
    Conv2d(in_channels=256, out_channels=6 * num_classes, kernel_size=3, padding=1),
    Conv2d(in_channels=256, out_channels=6 * num_classes, kernel_size=3, padding=1),
    Conv2d(in_channels=64, out_channels=6 * num_classes, kernel_size=1),
])

ssd_model = SSD(num_classes, base_net, source_layer_indexes, extras, classification_headers, regression_headers, is_test=False, config=config)
ssd_model.eval()
# Out:
# SSD(
#   (base_net): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): hswish()
#     (3): BlockNoDw(
#       (se): SeModule(
#         (se): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(8, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): Conv2d(2, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (5): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): hsigmoid()
#         )
#       )
#       (conv1): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): ReLU(inplace=True)
#       (conv2): Conv2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BlockNoDw(
#       (conv1): Conv2d(8, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): ReLU(inplace=True)
#       (conv2): Conv2d(72, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (5): BlockNoDw(
#       (conv1): Conv2d(12, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): ReLU(inplace=True)
#       (conv2): Conv2d(88, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (6): BlockNoDw(
#       (se): SeModule(
#         (se): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(20, 5, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): Conv2d(5, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (5): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): hsigmoid()
#         )
#       )
#       (conv1): Conv2d(12, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(96, 20, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (7): BlockNoDw(
#       (se): SeModule(
#         (se): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(20, 5, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): Conv2d(5, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (5): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): hsigmoid()
#         )
#       )
#       (conv1): Conv2d(20, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(240, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (8): BlockNoDw(
#       (se): SeModule(
#         (se): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(20, 5, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): Conv2d(5, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (5): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): hsigmoid()
#         )
#       )
#       (conv1): Conv2d(20, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(240, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (9): BlockNoDw(
#       (se): SeModule(
#         (se): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (5): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): hsigmoid()
#         )
#       )
#       (conv1): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(120, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(20, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): BlockNoDw(
#       (se): SeModule(
#         (se): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (5): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): hsigmoid()
#         )
#       )
#       (conv1): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(144, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (11): BlockNoDw(
#       (se): SeModule(
#         (se): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (5): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): hsigmoid()
#         )
#       )
#       (conv1): Conv2d(24, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(288, 48, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#       (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (12): BlockNoDw(
#       (se): SeModule(
#         (se): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (5): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): hsigmoid()
#         )
#       )
#       (conv1): Conv2d(48, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(576, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (13): BlockNoDw(
#       (se): SeModule(
#         (se): Sequential(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (5): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): hsigmoid()
#         )
#       )
#       (conv1): Conv2d(48, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(576, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (14): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (15): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): hswish()
#   )
#   (extras): ModuleList(
#     (0): BlockNoDw(
#       (conv1): Conv2d(288, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BlockNoDw(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BlockNoDw(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BlockNoDw(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nolinear1): hswish()
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (classification_headers): ModuleList(
#     (0): Conv2d(24, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(288, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): Conv2d(256, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): Conv2d(256, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Conv2d(64, 12, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (regression_headers): ModuleList(
#     (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(288, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): Conv2d(256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): Conv2d(256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (source_layer_add_ons): ModuleList()
# )

# %%
summary(ssd_model, (1, 3, 300, 300), device='cpu')
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# SSD                                                --                        --
# ├─ModuleList: 1-1                                  --                        --
# ├─ModuleList: 1-2                                  --                        --
# ├─ModuleList: 1-3                                  --                        --
# ├─ModuleList: 1-4                                  --                        --
# ├─Sequential: 1                                    --                        --
# │    └─Conv2d: 2-1                                 [1, 8, 150, 150]          216
# │    └─BatchNorm2d: 2-2                            [1, 8, 150, 150]          16
# │    └─hswish: 2-3                                 [1, 8, 150, 150]          --
# │    └─BlockNoDw: 2-4                              [1, 8, 75, 75]            --
# │    │    └─Conv2d: 3-1                            [1, 16, 150, 150]         128
# │    │    └─BatchNorm2d: 3-2                       [1, 16, 150, 150]         32
# │    │    └─ReLU: 3-3                              [1, 16, 150, 150]         --
# │    │    └─Conv2d: 3-4                            [1, 8, 75, 75]            1,152
# │    │    └─BatchNorm2d: 3-5                       [1, 8, 75, 75]            16
# │    │    └─SeModule: 3-6                          [1, 8, 75, 75]            52
# │    └─BlockNoDw: 2-5                              [1, 12, 38, 38]           --
# │    │    └─Conv2d: 3-7                            [1, 72, 75, 75]           576
# │    │    └─BatchNorm2d: 3-8                       [1, 72, 75, 75]           144
# │    │    └─ReLU: 3-9                              [1, 72, 75, 75]           --
# │    │    └─Conv2d: 3-10                           [1, 12, 38, 38]           7,776
# │    │    └─BatchNorm2d: 3-11                      [1, 12, 38, 38]           24
# │    └─BlockNoDw: 2-6                              [1, 12, 38, 38]           --
# │    │    └─Conv2d: 3-12                           [1, 88, 38, 38]           1,056
# │    │    └─BatchNorm2d: 3-13                      [1, 88, 38, 38]           176
# │    │    └─ReLU: 3-14                             [1, 88, 38, 38]           --
# │    │    └─Conv2d: 3-15                           [1, 12, 38, 38]           9,504
# │    │    └─BatchNorm2d: 3-16                      [1, 12, 38, 38]           24
# │    │    └─Sequential: 3-17                       [1, 12, 38, 38]           --
# │    └─BlockNoDw: 2-7                              [1, 20, 19, 19]           --
# │    │    └─Conv2d: 3-18                           [1, 96, 38, 38]           1,152
# │    │    └─BatchNorm2d: 3-19                      [1, 96, 38, 38]           192
# │    │    └─hswish: 3-20                           [1, 96, 38, 38]           --
# │    │    └─Conv2d: 3-21                           [1, 20, 19, 19]           48,000
# │    │    └─BatchNorm2d: 3-22                      [1, 20, 19, 19]           40
# │    │    └─SeModule: 3-23                         [1, 20, 19, 19]           250
# │    └─BlockNoDw: 2-8                              [1, 20, 19, 19]           --
# │    │    └─Conv2d: 3-24                           [1, 240, 19, 19]          4,800
# │    │    └─BatchNorm2d: 3-25                      [1, 240, 19, 19]          480
# │    │    └─hswish: 3-26                           [1, 240, 19, 19]          --
# │    │    └─Conv2d: 3-27                           [1, 20, 19, 19]           120,000
# │    │    └─BatchNorm2d: 3-28                      [1, 20, 19, 19]           40
# │    │    └─SeModule: 3-29                         [1, 20, 19, 19]           250
# │    │    └─Sequential: 3-30                       [1, 20, 19, 19]           --
# │    └─BlockNoDw: 2-9                              [1, 20, 19, 19]           --
# │    │    └─Conv2d: 3-31                           [1, 240, 19, 19]          4,800
# │    │    └─BatchNorm2d: 3-32                      [1, 240, 19, 19]          480
# │    │    └─hswish: 3-33                           [1, 240, 19, 19]          --
# │    │    └─Conv2d: 3-34                           [1, 20, 19, 19]           120,000
# │    │    └─BatchNorm2d: 3-35                      [1, 20, 19, 19]           40
# │    │    └─SeModule: 3-36                         [1, 20, 19, 19]           250
# │    │    └─Sequential: 3-37                       [1, 20, 19, 19]           --
# │    └─BlockNoDw: 2-10                             [1, 24, 19, 19]           --
# │    │    └─Conv2d: 3-38                           [1, 120, 19, 19]          2,400
# │    │    └─BatchNorm2d: 3-39                      [1, 120, 19, 19]          240
# │    │    └─hswish: 3-40                           [1, 120, 19, 19]          --
# │    │    └─Conv2d: 3-41                           [1, 24, 19, 19]           72,000
# │    │    └─BatchNorm2d: 3-42                      [1, 24, 19, 19]           48
# │    │    └─SeModule: 3-43                         [1, 24, 19, 19]           348
# │    │    └─Sequential: 3-44                       [1, 24, 19, 19]           528
# │    └─BlockNoDw: 2-11                             [1, 24, 19, 19]           --
# │    │    └─Conv2d: 3-45                           [1, 144, 19, 19]          3,456
# │    │    └─BatchNorm2d: 3-46                      [1, 144, 19, 19]          288
# │    │    └─hswish: 3-47                           [1, 144, 19, 19]          --
# │    │    └─Conv2d: 3-48                           [1, 24, 19, 19]           86,400
# │    │    └─BatchNorm2d: 3-49                      [1, 24, 19, 19]           48
# │    │    └─SeModule: 3-50                         [1, 24, 19, 19]           348
# │    │    └─Sequential: 3-51                       [1, 24, 19, 19]           --
# ├─ModuleList: 1-2                                  --                        --
# │    └─Conv2d: 2-12                                [1, 12, 19, 19]           2,604
# ├─ModuleList: 1-3                                  --                        --
# │    └─Conv2d: 2-13                                [1, 24, 19, 19]           5,208
# ├─Sequential: 1                                    --                        --
# │    └─BlockNoDw: 2-14                             [1, 48, 10, 10]           --
# │    │    └─Conv2d: 3-52                           [1, 288, 19, 19]          6,912
# │    │    └─BatchNorm2d: 3-53                      [1, 288, 19, 19]          576
# │    │    └─hswish: 3-54                           [1, 288, 19, 19]          --
# │    │    └─Conv2d: 3-55                           [1, 48, 10, 10]           345,600
# │    │    └─BatchNorm2d: 3-56                      [1, 48, 10, 10]           96
# │    │    └─SeModule: 3-57                         [1, 48, 10, 10]           1,272
# │    └─BlockNoDw: 2-15                             [1, 48, 10, 10]           --
# │    │    └─Conv2d: 3-58                           [1, 576, 10, 10]          27,648
# │    │    └─BatchNorm2d: 3-59                      [1, 576, 10, 10]          1,152
# │    │    └─hswish: 3-60                           [1, 576, 10, 10]          --
# │    │    └─Conv2d: 3-61                           [1, 48, 10, 10]           691,200
# │    │    └─BatchNorm2d: 3-62                      [1, 48, 10, 10]           96
# │    │    └─SeModule: 3-63                         [1, 48, 10, 10]           1,272
# │    │    └─Sequential: 3-64                       [1, 48, 10, 10]           --
# │    └─BlockNoDw: 2-16                             [1, 48, 10, 10]           --
# │    │    └─Conv2d: 3-65                           [1, 576, 10, 10]          27,648
# │    │    └─BatchNorm2d: 3-66                      [1, 576, 10, 10]          1,152
# │    │    └─hswish: 3-67                           [1, 576, 10, 10]          --
# │    │    └─Conv2d: 3-68                           [1, 48, 10, 10]           691,200
# │    │    └─BatchNorm2d: 3-69                      [1, 48, 10, 10]           96
# │    │    └─SeModule: 3-70                         [1, 48, 10, 10]           1,272
# │    │    └─Sequential: 3-71                       [1, 48, 10, 10]           --
# │    └─Conv2d: 2-17                                [1, 288, 10, 10]          13,824
# │    └─BatchNorm2d: 2-18                           [1, 288, 10, 10]          576
# │    └─hswish: 2-19                                [1, 288, 10, 10]          --
# ├─ModuleList: 1-2                                  --                        --
# │    └─Conv2d: 2-20                                [1, 12, 10, 10]           31,116
# ├─ModuleList: 1-3                                  --                        --
# │    └─Conv2d: 2-21                                [1, 24, 10, 10]           62,232
# ├─ModuleList: 1-1                                  --                        --
# │    └─BlockNoDw: 2-22                             [1, 512, 5, 5]            --
# │    │    └─Conv2d: 3-72                           [1, 256, 10, 10]          73,728
# │    │    └─BatchNorm2d: 3-73                      [1, 256, 10, 10]          512
# │    │    └─hswish: 3-74                           [1, 256, 10, 10]          --
# │    │    └─Conv2d: 3-75                           [1, 512, 5, 5]            1,179,648
# │    │    └─BatchNorm2d: 3-76                      [1, 512, 5, 5]            1,024
# ├─ModuleList: 1-2                                  --                        --
# │    └─Conv2d: 2-23                                [1, 12, 5, 5]             55,308
# ├─ModuleList: 1-3                                  --                        --
# │    └─Conv2d: 2-24                                [1, 24, 5, 5]             110,616
# ├─ModuleList: 1-1                                  --                        --
# │    └─BlockNoDw: 2-25                             [1, 256, 3, 3]            --
# │    │    └─Conv2d: 3-77                           [1, 128, 5, 5]            65,536
# │    │    └─BatchNorm2d: 3-78                      [1, 128, 5, 5]            256
# │    │    └─hswish: 3-79                           [1, 128, 5, 5]            --
# │    │    └─Conv2d: 3-80                           [1, 256, 3, 3]            294,912
# │    │    └─BatchNorm2d: 3-81                      [1, 256, 3, 3]            512
# ├─ModuleList: 1-2                                  --                        --
# │    └─Conv2d: 2-26                                [1, 12, 3, 3]             27,660
# ├─ModuleList: 1-3                                  --                        --
# │    └─Conv2d: 2-27                                [1, 24, 3, 3]             55,320
# ├─ModuleList: 1-1                                  --                        --
# │    └─BlockNoDw: 2-28                             [1, 256, 2, 2]            --
# │    │    └─Conv2d: 3-82                           [1, 128, 3, 3]            32,768
# │    │    └─BatchNorm2d: 3-83                      [1, 128, 3, 3]            256
# │    │    └─hswish: 3-84                           [1, 128, 3, 3]            --
# │    │    └─Conv2d: 3-85                           [1, 256, 2, 2]            294,912
# │    │    └─BatchNorm2d: 3-86                      [1, 256, 2, 2]            512
# ├─ModuleList: 1-2                                  --                        --
# │    └─Conv2d: 2-29                                [1, 12, 2, 2]             27,660
# ├─ModuleList: 1-3                                  --                        --
# │    └─Conv2d: 2-30                                [1, 24, 2, 2]             55,320
# ├─ModuleList: 1-1                                  --                        --
# │    └─BlockNoDw: 2-31                             [1, 64, 1, 1]             --
# │    │    └─Conv2d: 3-87                           [1, 64, 2, 2]             16,384
# │    │    └─BatchNorm2d: 3-88                      [1, 64, 2, 2]             128
# │    │    └─hswish: 3-89                           [1, 64, 2, 2]             --
# │    │    └─Conv2d: 3-90                           [1, 64, 1, 1]             36,864
# │    │    └─BatchNorm2d: 3-91                      [1, 64, 1, 1]             128
# ├─ModuleList: 1-2                                  --                        --
# │    └─Conv2d: 2-32                                [1, 12, 1, 1]             780
# ├─ModuleList: 1-3                                  --                        --
# │    └─Conv2d: 2-33                                [1, 24, 1, 1]             1,560
# ====================================================================================================
# Total params: 4,732,826
# Trainable params: 4,732,826
# Non-trainable params: 0
# Total mult-adds (M): 454.84
# ====================================================================================================
# Input size (MB): 1.08
# Forward/backward pass size (MB): 30.79
# Params size (MB): 18.93
# Estimated Total Size (MB): 50.81
# ====================================================================================================

# %%
out = ssd_model(torch.randn(1, 3, 300, 300))
out[0].shape, out[1].shape
# Out:
# (torch.Size([1, 3000, 2]), torch.Size([1, 3000, 4]))

# %%
print(torch.__version__)

t_model = torch.jit.trace(model, torch.randn(1, 3, 300, 300))
torch.jit.save(t_model, 'mb3-rpi-ssd.torchscript')
# Out:
# 1.8.0+cpu
# C:\Development\anaconda3\envs\lpcv\lib\site-packages\torch\_jit_internal.py:603: LightningDeprecationWarning: The `LightningModule.datamodule` property is deprecated in v1.3 and will be removed in v1.5. Access the datamodule through using `self.trainer.datamodule` instead.
#   if hasattr(mod, name):
# C:\Development\anaconda3\envs\lpcv\lib\site-packages\torch\_jit_internal.py:603: LightningDeprecationWarning: The `LightningModule.loaded_optimizer_states_dict` property is deprecated in v1.4 and will be removed in v1.6.
#   if hasattr(mod, name):
